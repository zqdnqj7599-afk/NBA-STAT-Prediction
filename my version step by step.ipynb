# %%
from nba_api.stats.static import players, teams as teams_static
from nba_api.stats.endpoints import playergamelog, commonallplayers, commonteamroster
from tqdm.auto import tqdm
import pandas as pd
import time
import random

# %%
# получаем всех игроков для сезона
def get_all_players(season):
    teams_list = teams_static.get_teams()
    player_map = {}
    for team in tqdm(teams_list, desc ='Processing Teams'):
        team_id = team.get('id')
        try:
            time.sleep(1.6)
            roster = commonteamroster.CommonTeamRoster(team_id=team_id, season=season)
            roster_df = roster.get_data_frames()[0]
        except Exception as e:
            print(f"Error fetching roster for team ID {team['full_name']}: {e}")
            continue
        time.sleep(1.6)
        for _, row in roster_df.iterrows():
            player_map[row['PLAYER_ID']] = {
            'PLAYER_NAME' : row['PLAYER'],
            'TEAM_ID' : team_id,
            'TEAM_NAME' : team.get('full_name'),
            'POSITION' : row['POSITION'],
            'HEIGHT' : row['HEIGHT'],
            'WEIGHT' : row['WEIGHT'],
            'AGE' : row['AGE']
            }
    df_players = pd.DataFrame.from_dict(player_map, orient='index').reset_index().rename(columns={'index':'PLAYER_ID'})
    return df_players

# получаем лог игроков для сезона
def get_player_game_logs(player_ids, season):
    all_game_logs = []
    for player_id in tqdm(player_ids, desc='Processing Players'):
        try:
            time.sleep(1.6)
            gamelog = playergamelog.PlayerGameLog(player_id=player_id, season=season)
            gamelog_df = gamelog.get_data_frames()[0]
            all_game_logs.append(gamelog_df)
        except Exception as e:
            print(f"Error fetching game log for player ID {player_id}: {e}")
            continue
    if all_game_logs:
        combined_game_logs = pd.concat(all_game_logs, ignore_index=True)
    else:
        combined_game_logs = pd.DataFrame()
    return combined_game_logs

# %%
players_2025 = get_all_players('2024-25')
players_2025
# Out:
# Processing Teams:   0%|          | 0/30 [00:00<?, ?it/s]
#      PLAYER_ID     PLAYER_NAME     TEAM_ID          TEAM_NAME POSITION HEIGHT  \
# 0      1631210    Jacob Toppin  1610612737      Atlanta Hawks        F    6-8
# 1      1630552   Jalen Johnson  1610612737      Atlanta Hawks        F    6-8
# 2      1630811  Keaton Wallace  1610612737      Atlanta Hawks        G    6-3
# 3      1627747    Caris LeVert  1610612737      Atlanta Hawks        G    6-6
# 4      1641723     Kobe Bufkin  1610612737      Atlanta Hawks        G    6-4
# ..         ...             ...         ...                ...      ...    ...
# 529    1641706  Brandon Miller  1610612766  Charlotte Hornets        F    6-7
# 530    1642354      KJ Simpson  1610612766  Charlotte Hornets        G    6-0
# 531     203552      Seth Curry  1610612766  Charlotte Hornets        G    6-1
# 532    1642275  Tidjane Salaün  1610612766  Charlotte Hornets        F    6-8
# 533     201959      Taj Gibson  1610612766  Charlotte Hornets        F    6-9
#
#     WEIGHT   AGE
# 0      200  25.0
# 1      219  23.0
# 2      185  26.0
# 3      205  30.0
# 4      195  21.0
# ..     ...   ...
# 529    200  22.0
# 530    189  22.0
# 531    185  34.0
# 532    207  19.0
# 533    232  40.0
#
# [534 rows x 8 columns]

# %%
all_game_logs = []
for player_id in tqdm(players_2025['PLAYER_ID'], desc='Processing Players'):
    try:
        time.sleep(1.6)
        gamelog = playergamelog.PlayerGameLog(player_id=player_id, season='2024-25')
        gamelog_df = gamelog.get_data_frames()[0]
        all_game_logs.append(gamelog_df)
    except Exception as e:
        print(f"Error fetching game log for player ID {player_id}: {e}")
        continue
combined_game_logs_2025 = pd.concat(all_game_logs, ignore_index=True)
combined_game_logs_2025
# Out:
# Processing Players:   0%|          | 0/534 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 4
#       2 for player_id in tqdm(players_2025['PLAYER_ID'], desc='Processing Players'):
#       3     try:
# ----> 4         time.sleep(1.6)
#       5         gamelog = playergamelog.PlayerGameLog(player_id=player_id, season='2024-25')
#       6         gamelog_df = gamelog.get_data_frames()[0]
#
# KeyboardInterrupt:

# %%
pd.options.display.max_columns = None

combined_game_logs_2025['GAME_DATE']  = pd.to_datetime(combined_game_logs_2025['GAME_DATE'])
combined_game_logs_2025.set_index('GAME_DATE', inplace=True)

# %%
# features engineering

combined_game_logs_2025.sort_values(by=['Player_ID', 'GAME_DATE'], inplace=True)

stats = ['PTS', 'AST', 'REB', 'STL', 'BLK', 'TOV', 'FG_PCT', 'FG3_PCT', 'FT_PCT', 'PLUS_MINUS']
for stat in stats:
    combined_game_logs_2025[f'PREV_10_{stat}'] = combined_game_logs_2025.groupby('Player_ID')[stat].transform(lambda x: x.shift(1).rolling(window=10, min_periods=10).mean())

for stat in stats:
    combined_game_logs_2025[f'PREV_3_{stat}'] = combined_game_logs_2025.groupby('Player_ID')[stat].transform(lambda x: x.shift(1).rolling(window=10, min_periods=10).mean())

for stat in stats:
    combined_game_logs_2025[f'last_v_{stat}'] = combined_game_logs_2025.groupby('Player_ID')[stat].shift(1)

combined_game_logs_2025['stdt PTS 10'] = combined_game_logs_2025.groupby('Player_ID')['PTS'].transform(lambda x: x.shift(1).rolling(window=10, min_periods=10).std())  
combined_game_logs_2025['stdt PTS 3'] = combined_game_logs_2025.groupby('Player_ID')['PTS'].transform(lambda x: x.shift(1).rolling(window=3, min_periods=3).std())      

combined_game_logs_2025 = combined_game_logs_2025.reset_index(drop=True)

# %%
combined_game_logs_2025.head(20)
# Out:
#     index  GAME_DATE SEASON_ID Player_ID     Game_ID      MATCHUP WL MIN FGM  \
# 0       0 2024-10-22     22024      2544  0022400062  LAL vs. MIN  W  35   7
# 1       1 2024-10-25     22024      2544  0022400085  LAL vs. PHX  W  35   7
# 2       2 2024-10-26     22024      2544  0022400096  LAL vs. SAC  W  34  12
# 3       3 2024-10-28     22024      2544  0022400111    LAL @ PHX  L  36   3
# 4       4 2024-10-30     22024      2544  0022400118    LAL @ CLE  L  29   9
# 5       5 2024-11-01     22024      2544  0022400137    LAL @ TOR  W  36   9
# 6       6 2024-11-04     22024      2544  0022400156    LAL @ DET  L  40   7
# 7       7 2024-11-06     22024      2544  0022400174    LAL @ MEM  L  35  15
# 8       8 2024-11-08     22024      2544  0022400195  LAL vs. PHI  W  34   9
# 9       9 2024-11-10     22024      2544  0022400211  LAL vs. TOR  W  35   6
# 10     10 2024-11-13     22024      2544  0022400225  LAL vs. MEM  W  37  13
# 11     11 2024-11-15     22024      2544  0022400015    LAL @ SAS  W  38   6
# 12     12 2024-11-16     22024      2544  0022400231    LAL @ NOP  W  37   8
# 13     13 2024-11-19     22024      2544  0022400026  LAL vs. UTA  W  34   9
# 14     14 2024-11-21     22024      2544  0022400263  LAL vs. ORL  L  37  12
# 15     15 2024-11-23     22024      2544  0022400270  LAL vs. DEN  L  35   7
# 16     16 2024-11-26     22024      2544  0022400039    LAL @ PHX  L  35   7
# 17     17 2024-11-27     22024      2544  0022400296    LAL @ SAS  W  33   8
# 18     18 2024-11-29     22024      2544  0022400048  LAL vs. OKC  L  34   5
# 19     19 2024-12-01     22024      2544  0022400311    LAL @ UTA  W  36  12
#
#    FGA  FG_PCT FG3M FG3A  FG3_PCT FTM FTA  FT_PCT OREB DREB REB AST STL BLK  \
# 0   16   0.438    1    4    0.250   1   1   1.000    0    5   5   4   0   2
# 1   13   0.538    2    5    0.400   5   8   0.625    0    4   4   8   0   0
# 2   22   0.545    4    9    0.444   4   4   1.000    0   14  14  10   0   1
# 3   14   0.214    2    5    0.400   3   6   0.500    0    5   5   8   1   0
# 4   13   0.692    1    3    0.333   7   7   1.000    1    5   6   3   0   0
# 5   17   0.529    5    8    0.625   4   6   0.667    0    6   6  10   1   0
# 6   16   0.438    1    2    0.500   5   5   1.000    1    7   8  11   2   0
# 7   24   0.625    6   11    0.545   3   4   0.750    0    7   7   6   1   0
# 8   14   0.643    2    4    0.500   1   1   1.000    0   12  12  13   0   3
# 9   14   0.429    0    3    0.000   7   7   1.000    2    8  10  16   1   0
# 10  22   0.591    4    7    0.571   5   8   0.625    1   11  12  14   1   0
# 11  12   0.500    1    4    0.250   2   4   0.500    1   15  16  12   1   0
# 12  19   0.421    2    7    0.286   3   5   0.600    4    3   7   5   1   0
# 13  17   0.529    1    5    0.200   7  11   0.636    0    2   2  12   0   0
# 14  22   0.545    5    9    0.556   2   4   0.500    2    8  10   7   0   1
# 15  17   0.412    1    4    0.250   3   3   1.000    0    6   6   7   3   0
# 16  16   0.438    2    7    0.286   2   2   1.000    1    7   8  10   0   0
# 17  18   0.444    0    2    0.000   0   0   0.000    3    7  10  11   1   1
# 18  13   0.385    0    4    0.000   2   2   1.000    0    8   8   6   0   0
# 19  28   0.429    0    9    0.000   3   3   1.000    1    4   5  14   0   2
#
#    TOV PF PTS PLUS_MINUS VIDEO_AVAILABLE  PREV_PTS  PREV_AST  PREV_REB  \
# 0    2  3  16         -6               1       NaN       NaN       NaN
# 1    2  1  21         14               1       NaN       NaN       NaN
# 2    5  3  32         13               1       NaN       NaN       NaN
# 3    2  1  11        -17               1       NaN       NaN       NaN
# 4    6  2  26        -17               1       NaN       NaN       NaN
# 5    0  1  27         11               1      21.2       6.6       6.8
# 6    1  1  20        -16               1      23.4       7.8       7.0
# 7    5  2  39        -21               1      23.2       8.4       7.8
# 8    2  0  21         12               1      24.6       7.6       6.4
# 9    3  0  19         13               1      26.6       8.6       7.8
# 10   6  2  35          3               1      25.2      11.2       8.6
# 11   7  0  15          3               1      26.8      12.0       9.8
# 12   6  1  21          1               1      25.8      12.2      11.4
# 13   4  1  26         -5               1      22.2      12.0      11.4
# 14   4  0  31         -8               1      23.2      11.8       9.4
# 15   6  3  18        -25               1      25.6      10.0       9.4
# 16   5  0  18        -30               1      22.2       8.6       8.2
# 17   5  0  16          4               1      22.8       8.2       6.6
# 18   5  0  12        -12               1      21.8       9.4       7.2
# 19   3  1  27          0               1      19.0       8.2       8.4
#
#     PREV_STL  PREV_BLK  PREV_TOV  PREV_FG_PCT  PREV_FG3_PCT  PREV_FT_PCT  \
# 0        NaN       NaN       NaN          NaN           NaN          NaN
# 1        NaN       NaN       NaN          NaN           NaN          NaN
# 2        NaN       NaN       NaN          NaN           NaN          NaN
# 3        NaN       NaN       NaN          NaN           NaN          NaN
# 4        NaN       NaN       NaN          NaN           NaN          NaN
# 5        0.2       0.6       3.4       0.4854        0.3654       0.8250
# 6        0.4       0.2       3.0       0.5036        0.4404       0.7584
# 7        0.8       0.2       2.8       0.4836        0.4604       0.8334
# 8        1.0       0.0       2.8       0.4996        0.4806       0.7834
# 9        0.8       0.6       2.8       0.5854        0.5006       0.8834
# 10       1.0       0.6       2.2       0.5328        0.4340       0.8834
# 11       1.0       0.6       3.4       0.5452        0.4232       0.8750
# 12       0.8       0.6       4.6       0.5576        0.3732       0.7750
# 13       0.8       0.6       4.8       0.5168        0.3214       0.7450
# 14       0.8       0.0       5.2       0.4940        0.2614       0.6722
# 15       0.6       0.2       5.4       0.5172        0.3726       0.5722
# 16       1.0       0.2       5.4       0.4814        0.3084       0.6472
# 17       0.8       0.2       5.0       0.4690        0.3156       0.7472
# 18       0.8       0.4       4.8       0.4736        0.2584       0.6272
# 19       0.8       0.4       5.0       0.4448        0.2184       0.7000
#
#     PREV_PLUS_MINUS  PREV_10_PTS  PREV_10_AST  PREV_10_REB  PREV_10_STL  \
# 0               NaN          NaN          NaN          NaN          NaN
# 1               NaN          NaN          NaN          NaN          NaN
# 2               NaN          NaN          NaN          NaN          NaN
# 3               NaN          NaN          NaN          NaN          NaN
# 4               NaN          NaN          NaN          NaN          NaN
# 5              -2.6          NaN          NaN          NaN          NaN
# 6               0.8          NaN          NaN          NaN          NaN
# 7              -5.2          NaN          NaN          NaN          NaN
# 8             -12.0          NaN          NaN          NaN          NaN
# 9              -6.2          NaN          NaN          NaN          NaN
# 10             -0.2         23.2          8.9          7.7          0.6
# 11             -1.8         25.1          9.9          8.4          0.7
# 12              2.0         24.5         10.3          9.6          0.8
# 13              6.4         23.4          9.8          8.9          0.9
# 14              3.0         24.9         10.2          8.6          0.8
# 15             -1.2         25.4         10.6          9.0          0.8
# 16             -6.8         24.5         10.3          9.0          1.0
# 17            -13.4         24.3         10.2          9.0          0.8
# 18            -12.8         22.0         10.7          9.3          0.8
# 19            -14.2         21.1         10.0          8.9          0.8
#
#     PREV_10_BLK  PREV_10_TOV  PREV_10_FG_PCT  PREV_10_FG3_PCT  PREV_10_FT_PCT  \
# 0           NaN          NaN             NaN              NaN             NaN
# 1           NaN          NaN             NaN              NaN             NaN
# 2           NaN          NaN             NaN              NaN             NaN
# 3           NaN          NaN             NaN              NaN             NaN
# 4           NaN          NaN             NaN              NaN             NaN
# 5           NaN          NaN             NaN              NaN             NaN
# 6           NaN          NaN             NaN              NaN             NaN
# 7           NaN          NaN             NaN              NaN             NaN
# 8           NaN          NaN             NaN              NaN             NaN
# 9           NaN          NaN             NaN              NaN             NaN
# 10          0.6          2.8          0.5091           0.3997          0.8542
# 11          0.4          3.2          0.5244           0.4318          0.8167
# 12          0.4          3.7          0.5206           0.4168          0.8042
# 13          0.3          3.8          0.5082           0.4010          0.7642
# 14          0.3          4.0          0.5397           0.3810          0.7778
# 15          0.4          3.8          0.5250           0.4033          0.7278
# 16          0.4          4.4          0.5133           0.3658          0.7611
# 17          0.4          4.8          0.5133           0.3444          0.7611
# 18          0.5          4.8          0.4952           0.2899          0.6861
# 19          0.2          5.1          0.4694           0.2399          0.6861
#
#     PREV_10_PLUS_MINUS  PREV_3_PTS  PREV_3_AST  PREV_3_REB  PREV_3_STL  \
# 0                  NaN         NaN         NaN         NaN         NaN
# 1                  NaN         NaN         NaN         NaN         NaN
# 2                  NaN         NaN         NaN         NaN         NaN
# 3                  NaN         NaN         NaN         NaN         NaN
# 4                  NaN         NaN         NaN         NaN         NaN
# 5                  NaN         NaN         NaN         NaN         NaN
# 6                  NaN         NaN         NaN         NaN         NaN
# 7                  NaN         NaN         NaN         NaN         NaN
# 8                  NaN         NaN         NaN         NaN         NaN
# 9                  NaN         NaN         NaN         NaN         NaN
# 10                -1.4        23.2         8.9         7.7         0.6
# 11                -0.5        25.1         9.9         8.4         0.7
# 12                -1.6        24.5        10.3         9.6         0.8
# 13                -2.8        23.4         9.8         8.9         0.9
# 14                -1.6        24.9        10.2         8.6         0.8
# 15                -0.7        25.4        10.6         9.0         0.8
# 16                -4.3        24.5        10.3         9.0         1.0
# 17                -5.7        24.3        10.2         9.0         0.8
# 18                -3.2        22.0        10.7         9.3         0.8
# 19                -5.6        21.1        10.0         8.9         0.8
#
#     PREV_3_BLK  PREV_3_TOV  PREV_3_FG_PCT  PREV_3_FG3_PCT  PREV_3_FT_PCT  \
# 0          NaN         NaN            NaN             NaN            NaN
# 1          NaN         NaN            NaN             NaN            NaN
# 2          NaN         NaN            NaN             NaN            NaN
# 3          NaN         NaN            NaN             NaN            NaN
# 4          NaN         NaN            NaN             NaN            NaN
# 5          NaN         NaN            NaN             NaN            NaN
# 6          NaN         NaN            NaN             NaN            NaN
# 7          NaN         NaN            NaN             NaN            NaN
# 8          NaN         NaN            NaN             NaN            NaN
# 9          NaN         NaN            NaN             NaN            NaN
# 10         0.6         2.8         0.5091          0.3997         0.8542
# 11         0.4         3.2         0.5244          0.4318         0.8167
# 12         0.4         3.7         0.5206          0.4168         0.8042
# 13         0.3         3.8         0.5082          0.4010         0.7642
# 14         0.3         4.0         0.5397          0.3810         0.7778
# 15         0.4         3.8         0.5250          0.4033         0.7278
# 16         0.4         4.4         0.5133          0.3658         0.7611
# 17         0.4         4.8         0.5133          0.3444         0.7611
# 18         0.5         4.8         0.4952          0.2899         0.6861
# 19         0.2         5.1         0.4694          0.2399         0.6861
#
#     PREV_3_PLUS_MINUS last_v_PTS last_v_AST last_v_REB last_v_STL last_v_BLK  \
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN         16          4          5          0          2
# 2                 NaN         21          8          4          0          0
# 3                 NaN         32         10         14          0          1
# 4                 NaN         11          8          5          1          0
# 5                 NaN         26          3          6          0          0
# 6                 NaN         27         10          6          1          0
# 7                 NaN         20         11          8          2          0
# 8                 NaN         39          6          7          1          0
# 9                 NaN         21         13         12          0          3
# 10               -1.4         19         16         10          1          0
# 11               -0.5         35         14         12          1          0
# 12               -1.6         15         12         16          1          0
# 13               -2.8         21          5          7          1          0
# 14               -1.6         26         12          2          0          0
# 15               -0.7         31          7         10          0          1
# 16               -4.3         18          7          6          3          0
# 17               -5.7         18         10          8          0          0
# 18               -3.2         16         11         10          1          1
# 19               -5.6         12          6          8          0          0
#
#    last_v_TOV  last_v_FG_PCT  last_v_FG3_PCT  last_v_FT_PCT last_v_PLUS_MINUS  \
# 0         NaN            NaN             NaN            NaN               NaN
# 1           2          0.438           0.250          1.000                -6
# 2           2          0.538           0.400          0.625                14
# 3           5          0.545           0.444          1.000                13
# 4           2          0.214           0.400          0.500               -17
# 5           6          0.692           0.333          1.000               -17
# 6           0          0.529           0.625          0.667                11
# 7           1          0.438           0.500          1.000               -16
# 8           5          0.625           0.545          0.750               -21
# 9           2          0.643           0.500          1.000                12
# 10          3          0.429           0.000          1.000                13
# 11          6          0.591           0.571          0.625                 3
# 12          7          0.500           0.250          0.500                 3
# 13          6          0.421           0.286          0.600                 1
# 14          4          0.529           0.200          0.636                -5
# 15          4          0.545           0.556          0.500                -8
# 16          6          0.412           0.250          1.000               -25
# 17          5          0.438           0.286          1.000               -30
# 18          5          0.444           0.000          0.000                 4
# 19          5          0.385           0.000          1.000               -12
#
#     stdt PTS 10  stdt PTS 3
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
# 3           NaN    8.185353
# 4           NaN   10.503968
# 5           NaN   10.816654
# 6           NaN    8.962886
# 7           NaN    3.785939
# 8           NaN    9.609024
# 9           NaN   10.692677
# 10     8.080154   11.015141
# 11     8.425490    8.717798
# 12     8.947377   10.583005
# 13     8.591986   10.263203
# 14     7.415449    5.507571
# 15     7.662318    5.000000
# 16     7.975657    6.557439
# 17     8.124722    7.505553
# 18     6.616478    1.154701
# 19     7.340148    3.055050

# %%
# Out:
#      PLAYER_ID     PLAYER_NAME     TEAM_ID          TEAM_NAME POSITION HEIGHT  \
# 0      1631210    Jacob Toppin  1610612737      Atlanta Hawks        F    6-8
# 1      1630552   Jalen Johnson  1610612737      Atlanta Hawks        F    6-8
# 2      1630811  Keaton Wallace  1610612737      Atlanta Hawks        G    6-3
# 3      1627747    Caris LeVert  1610612737      Atlanta Hawks        G    6-6
# 4      1641723     Kobe Bufkin  1610612737      Atlanta Hawks        G    6-4
# ..         ...             ...         ...                ...      ...    ...
# 529    1641706  Brandon Miller  1610612766  Charlotte Hornets        F    6-7
# 530    1642354      KJ Simpson  1610612766  Charlotte Hornets        G    6-0
# 531     203552      Seth Curry  1610612766  Charlotte Hornets        G    6-1
# 532    1642275  Tidjane Salaün  1610612766  Charlotte Hornets        F    6-8
# 533     201959      Taj Gibson  1610612766  Charlotte Hornets        F    6-9
#
#     WEIGHT   AGE
# 0      200  25.0
# 1      219  23.0
# 2      185  26.0
# 3      205  30.0
# 4      195  21.0
# ..     ...   ...
# 529    200  22.0
# 530    189  22.0
# 531    185  34.0
# 532    207  19.0
# 533    232  40.0
#
# [534 rows x 8 columns]
